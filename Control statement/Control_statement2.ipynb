# %%
amount=int(input('Enter amount: '))
five_hun=amount//500
amount=amount%500
two_hun=amount//200
amount=amount%200
hun=amount//100
if five_hun or two_hun:
  print('500 rupee notes will be :',five_hun)
  print('200 rupee notes will be :',two_hun)
# Out:
# Enter amount: 5400
# 500 rupee notes will be : 10
# 200 rupee notes will be : 2

# %%
#leap year  ==== >  normal (1-99)  ---> divisible by 4
# century year ===== x*100         ---> divisible by 400

# %%
year = int(input('Enter year: '))
if year%100:
      if year%4==0:
        print('leap year')
      else:
        print('not leap year')
else:
    if year%400==0:
      print('leap year')
    else :
      print('not leap year')
# Out:
# Enter year: 2100
# not leap year

# %%
#loops in python
# for loop
# while loop
# loop  ---->

# %%
#syntax
# sequence ---> list , strin , tuple, set

for var in sequence:
  expression

# %%
for i in "manish":
  print(i)
# Out:
# m
# a
# n
# i
# s
# h

# %%
for i in ['manish',10,'shan','jeet']:
  print(i)
# Out:
# manish
# 10
# shan
# jeet

# %%
l=['manish','shan','jeet']
for i in l:
  l.append(i)
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# shan
# jeet
# manish
# ...
